# %% [markdown]
# # 画像処理のテスト
#
# dataフォルダに格納されているdogとcatの2クラスの画像を分類するモデルを作成せよ。
#
# サンプル数
#
# - dog: 250枚
# - cat: 250枚
#
# 訓練データ: 全体の70%をランダムに（seed=0）
#
# AccuracyがValidationのデータに対して70%得られていること

# %%
from glob import glob
import os
import json
import numpy as np
import pandas as pd
from PIL import Image
import chainer
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = '../new_dataset/dataset/data/'

os.listdir(data_dir)
# Out:
# ['validation', 'test.zip', 'train']

# %%
train_dogs = glob(os.path.join(data_dir, 'train/dog/*.jpg'))
train_cats = glob(os.path.join(data_dir, 'train/cat/*.jpg'))
valid_dogs = glob(os.path.join(data_dir, 'validation/dog/*.jpg'))
valid_cats = glob(os.path.join(data_dir, 'validation/cat/*.jpg'))

len(train_dogs), len(train_cats), len(valid_dogs), len(valid_cats)
# Out:
# (1000, 1000, 400, 400)

# %% [markdown]
# ### データの確認

# %%
# サンプル的に画像を見てみる
np.random.seed(0)
plt.figure(figsize=(20, 10))
for i in range(5):
    sample_cat = np.random.choice(train_cats)
    sample_img = Image.open(sample_cat)
    plt.subplot(2, 5, i+1)
    plt.imshow(sample_img)
    
    sample_dog = np.random.choice(train_dogs)
    sample_img = Image.open(sample_dog)
    plt.subplot(2, 5, i+6)
    plt.imshow(sample_img)

plt.show()

# %% [markdown]
# 気づいたこと
# * 正方形に加工されている様子
# * 全身の画像や顔などの一部だけ写ってる画像もある
# * うさぎも写っているものもある
# * 肉球もある

# %%
# 犬猫データの結合
train_label = {
    'cat': 1,
    'dog': 0}

df = pd.DataFrame({
    'file_path': train_cats + train_dogs + valid_dogs + valid_cats,
})
df['label'] = df['file_path'].str.split('/', expand=True)[5]
df['dataset'] = df['file_path'].str.split('/', expand=True)[4]
df['target'] = df['label'].replace(train_label)
df.shape
# Out:
# (2800, 4)

# %%
df.head()
# Out:
#                                            file_path label dataset  target
# 0  ../new_dataset/dataset/data/train/cat/train_ca...   cat   train       1
# 1  ../new_dataset/dataset/data/train/cat/train_ca...   cat   train       1
# 2  ../new_dataset/dataset/data/train/cat/train_ca...   cat   train       1
# 3  ../new_dataset/dataset/data/train/cat/train_ca...   cat   train       1
# 4  ../new_dataset/dataset/data/train/cat/train_ca...   cat   train       1

# %%
df.tail()
# Out:
#                                               file_path label     dataset  \
# 2795  ../new_dataset/dataset/data/validation/cat/val...   cat  validation
# 2796  ../new_dataset/dataset/data/validation/cat/val...   cat  validation
# 2797  ../new_dataset/dataset/data/validation/cat/val...   cat  validation
# 2798  ../new_dataset/dataset/data/validation/cat/val...   cat  validation
# 2799  ../new_dataset/dataset/data/validation/cat/val...   cat  validation
#
#       target
# 2795       1
# 2796       1
# 2797       1
# 2798       1
# 2799       1

# %%
# 画像サイズを調べる
for i, row in df.iterrows():
    img = cv2.imread(row['file_path'])
    df.loc[i, 'height'] = img.shape[0]
    df.loc[i, 'width'] = img.shape[1]
    df.loc[i, 'channel'] = img.shape[2]

# %%
df.iloc[np.random.choice(df.index, 5)]
# Out:
#                                               file_path label     dataset  \
# 277   ../new_dataset/dataset/data/train/cat/train_ca...   cat       train
# 1778  ../new_dataset/dataset/data/train/dog/train_do...   dog       train
# 1828  ../new_dataset/dataset/data/train/dog/train_do...   dog       train
#          338.,  249.,  421.,  483.,  244.,  412.,  349.,  266.,  330.,
#          270.,  160.,  450.,  287.,  492.,  139.,  439.,  288.,  267.,
#          343.,  348.,  145.,  375.,  374.,  480.,  258.,  140.,  495.,
#          381.,  425.,  133.,  449.,  161.,  333.,  294.,  430.,  398.,
#          279.,  447.,  406.,  199.,  471.,  240.,  383.,  155.,  380.,
#          395.,  489.,  367.,  461.,  225.,  459.,  153.,  360.,  331.,
#          344.,  254.,  169.,  428.,  306.,  448.,   80.,  292.,  107.,
#          352.,  356.,  313.,  481.,  498.,  296.,  353.,  201.,  403.,
#          400.,  220.,  323.,  150.,  198.,  478.,  490.,  322.,  392.,
#          308.,  278.,  271.,  458.,  191.,  216.,  426.,  444.,  366.,
#          372.,  457.,  332.,  286.,  168.,  401.,  410.,  433.,  446.,
#          445.,  144.,  283.,   75.,  302.,  265.,  346.,  156.,  419.,
#          382.,  151.,  359.,  336.,  370.,  436.,  324.,  149.,  215.,
#          189.,  273.,  321.,  252.,  218.,  291.,  376.,  484.,  451.,
#          309.,  230.,  121.,  476.,  464.,  335.,  429.,  488.,  253.,
#          407.,  440.,  424.,  491.,  405.,  328.,  219.,  396.,  390.,
#          217.,  238.,  369.,  111.,  397.,   95.,  422.,  154.,  190.,
#          465.,  237., 1023.,  175.,  181.,  272.,  260.,  187.,  394.,
#          477.,  194.,  334.,  159.,  479.,  413.,  204.,  391.,  467.,
#          415.,  325.,  214.,  251.,  224.,  411.,  487.,  486.,  262.,
#          371.,  389.,  362.,  243.,  293.,  442.,  264.,  162.,  246.,
#          257.,  314.,  100.,  454.,  310.,  297.,  404.,  119.,  307.,
#           98.,  441.,  146.,  443.,  432.,  301.,  474.,  208.,  423.,
#          284.,  342.,  128.,  275.,  202.,  182.,  171.,   59.,  373.,
#          414.,  340.,  233.,   90.,  357.,  337.,  141.,  269.,  295.,
#          365.,  138.,  329.,  318.,  170.,  316.,  274.,  364.,  496.,
#          157.,  408.,  326.,  473.,  468.,  377.,  420.,  347.,  124.,
#          120.,  363.,  460.,  358.,  164.,  245.,  247.,  222.,  135.,
#          327.,  212.,  117.,  210.,  417.,  305.,  317.,  485.,  285.,
#          178.,  434.,  115.,  385.,  393.,  387.,  494.,  268.,  466.,
#           73.,  290.,  227.,  125.,  418.,  378.,  226.,  113.,  174.,
#          386.,  311.,  248.,  289.,  341.,  236.,  438.,  110.,  195.,
#          142.,  263.,  241.,  183.,  192.,   69.,  213.,  196.,  303.,
#          207.,  416.,  228.,   74.,  355.,  475.,  134.,  482.,  453.,
#          229.,  455.,  437.,  361.,  137.,  456.,  462.]),
#  array([3.]))

# %% [markdown]
# * すべて同じサイズ・チャネル数も同じ画像と確認
# * サイズがばらばら

# %%
from chainer.datasets import TupleDataset

# %%
df['target'].value_counts()
# Out:
# 1    1400
# 0    1400
# Name: target, dtype: int64

# %%
train_df = df[df['dataset'] == 'train'].copy()
valid_df = df[df['dataset'] == 'validation'].copy()
valid_df = valid_df.reset_index()

train = TupleDataset(train_df['file_path'], train_df['target'].astype('int32'))
valid = TupleDataset(valid_df['file_path'], valid_df['target'].astype('int32'))

# %%
valid[0]
# Out:
# ('../new_dataset/dataset/data/validation/dog/val_dog0282.jpg', 0)
